# %% [markdown]
# # HEIGHT WEIGHT DF

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\hsbc_2019\\Desktop\\datasets\\height-weight.csv")
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
len(df) #length of dataframe
# Out:
# 25000

# %%
df['Weight(Pounds)'].mean()
# Out:
# 127.07942116079916

# %%
df['Weight(Pounds)'].plot(kind='hist')

# %%
df['Height(Inches)'].plot(kind='hist')

# %%
df.dtypes
# Out:
# Index               int64
# Height(Inches)    float64
# Weight(Pounds)    float64
# dtype: object

# %%
df.shape
# Out:
# (25000, 3)

# %%
df['Height(Inches)'].isna().unique()
# Out:
# array([False])

# %%
df['Weight(Pounds)'].isna().unique()
# Out:
# array([False])

# %%
df.columns
# Out:
# Index(['Index', 'Height(Inches)', 'Weight(Pounds)'], dtype='object')

# %%
df.max(axis=0)
# Out:
# Index             25000.0000
# Height(Inches)       75.1528
# Weight(Pounds)      170.9240
# dtype: float64

# %%
df['Height(Inches)'].unique()
# Out:
# array([65.78331, 71.51521, 69.39874, ..., 64.69855, 67.52918, 68.87761])

# %%
df['Weight(Pounds)'].unique()
# Out:
# array([112.9925, 136.4873, 153.0269, ..., 118.2655, 132.2682, 124.8742])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25000, step=1)

# %%
df.loc[2:5]
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971
# 5      6        68.69784        123.3024

# %%
df.iloc[2:5]
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
# df.isna()
df.dropna()
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331       112.99250
# 1          2        71.51521       136.48730
# 2          3        69.39874       153.02690
# 3          4        68.21660       142.33540
# 4          5        67.78781       144.29710
# 5          6        68.69784       123.30240
# 6          7        69.80204       141.49470
# 7          8        70.01472       136.46230
# 8          9        67.90265       112.37230
# 9         10        66.78236       120.66720
# 10        11        66.48769       127.45160
# 11        12        67.62333       114.14300
# 12        13        68.30248       125.61070
# 13        14        67.11656       122.46180
# 14        15        68.27967       116.08660
# 15        16        71.09160       139.99750
# 16        17        66.46100       129.50230
# 17        18        68.64927       142.97330
# 18        19        71.23033       137.90250
# 19        20        67.13118       124.04490
# ...

# %%
df.shape
# Out:
# (25000, 3)

# %%
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
df1 = df[df['Height(Inches)']==df['Height(Inches)'].max()]
df1
# Out:
#       Index  Height(Inches)  Weight(Pounds)
# 1893   1894         75.1528        146.9701

# %%
df2 = df[df['Height(Inches)']==df['Height(Inches)'].min()]
df2
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 13971  13972        60.27836        110.1138

# %%
df3 = pd.concat([df1,df2])
df3
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 1893    1894        75.15280        146.9701
# 13971  13972        60.27836        110.1138

# %%
df.groupby('Height(Inches)')
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331       112.99250
# 1          2        71.51521       136.48730
# 2          3        69.39874       153.02690
# 3          4        68.21660       142.33540
# 4          5        67.78781       144.29710
# 5          6        68.69784       123.30240
# 6          7        69.80204       141.49470
# 7          8        70.01472       136.46230
# 8          9        67.90265       112.37230
# 9         10        66.78236       120.66720
# 10        11        66.48769       127.45160
# 11        12        67.62333       114.14300
# 12        13        68.30248       125.61070
# 13        14        67.11656       122.46180
# 14        15        68.27967       116.08660
# 15        16        71.09160       139.99750
# 16        17        66.46100       129.50230
# 17        18        68.64927       142.97330
# 18        19        71.23033       137.90250
# 19        20        67.13118       124.04490
# ...

# %%
df.tail(3)
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742

# %%
df['height'] = df['Height(Inches)'].map(lambda inches: round(inches*0.0833,2))
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)  height
# 0      1        65.78331        112.9925    5.48
# 1      2        71.51521        136.4873    5.96
# 2      3        69.39874        153.0269    5.78
# 3      4        68.21660        142.3354    5.68
# 4      5        67.78781        144.2971    5.65

# %%
df['weight'] = df['Weight(Pounds)'].map(lambda pounds: round(pounds*0.453592,2))
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)  height  weight
# 0      1        65.78331        112.9925    5.48   51.25
# 1      2        71.51521        136.4873    5.96   61.91
# 2      3        69.39874        153.0269    5.78   69.41
# 3      4        68.21660        142.3354    5.68   64.56
# 4      5        67.78781        144.2971    5.65   65.45

# %% [markdown]
# # PANDAS TRAIN DF

# %%
df1 = pd.read_csv("C:\\Users\\hsbc_2019\\Desktop\\datasets\\pandas-train.csv")
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.columns
# Out:
# Index(['Index', 'Height(Inches)', 'Weight(Pounds)'], dtype='object')

# %%
df1['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df1['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df1['Name'].unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %%
df1['Cabin'].isna().unique()
# Out:
# array([ True, False])

# %%
df1['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df1['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
df1['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %% [markdown]
# # housing prices

# %%
df2 = pd.read_csv("C:\\Users\\hsbc_2019\\Desktop\\datasets\\housing_prices.csv")
df2.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df3 = pd.read_csv("C:\\Users\\hsbc_2019\\Desktop\\datasets\\resume_shortlist.csv")
df3.head()
# Out:
#   Degree  Grade  Work Experience Referral Shortlisted
# 0  BTech     50                4        N           N
# 1  MTech     40                4        N           N
# 2  MTech     95                5        N           Y
# 3  BTech     80                4        N           Y
# 4  MTech     60                5        N           Y

# %%
# df4 = pd.read_csv("C:\\Users\\hsbc_2019\\Desktop\\datasets\\pandas-Consumer.csv")
# df4.head()
