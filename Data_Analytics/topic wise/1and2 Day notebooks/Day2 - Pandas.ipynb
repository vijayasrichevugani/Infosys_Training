# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
bikeshare_data = pd.read_csv('C:\\Users\\hsbc_2019\\Desktop\\datasets\\bikesharedata.csv')
bikeshare_data.head()
# Out:
#    season  holiday  weekday  weathersit      temp     atemp       hum  \
# 0       1        0        6           2  0.344167  0.363625  0.805833
# 1       1        0        0           2  0.363478  0.353739  0.696087
# 2       1        0        1           1  0.196364  0.189405  0.437273
# 3       1        0        2           1  0.200000  0.212122  0.590435
# 4       1        0        3           1  0.226957  0.229270  0.436957
#
#    windspeed  users
# 0   0.160446    331
# 1   0.248539    131
# 2   0.248309    120
# 3   0.160296    108
# 4   0.186900     82

# %%
house_data = pd.read_csv('C:\\Users\\hsbc_2019\\Desktop\\datasets\\kc_house_data.csv')
house_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# How many people can you expect to rent a bike on any given day
bikeshare_data['users'].mean()
# Out:
# 848.1764705882352

# %%
bikeshare_data['users'].plot(kind="hist")

# %%
# What is the relationship between temp and no. of users? 
bikeshare_data.plot(kind='scatter',x='temp',y='users')

# %%
type(bikeshare_data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(bikeshare_data['users'])
# Out:
# pandas.core.series.Series

# %%
bikeshare_data.dtypes
# Out:
# season          int64
# holiday         int64
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# users           int64
# dtype: object

# %%
type(bikeshare_data.values)
# Out:
# numpy.ndarray

# %%
bikeshare_data.shape
# Out:
# (731, 9)

# %%
bikeshare_data.columns
# Out:
# Index(['season', 'holiday', 'weekday', 'weathersit', 'temp', 'atemp', 'hum',
#        'windspeed', 'users'],
#       dtype='object')

# %%
bikeshare_data = bikeshare_data.rename(columns={'atemp':'feels_like_temp'})

# %%
bikeshare_data.columns
# Out:
# Index(['season', 'holiday', 'weekday', 'weathersit', 'temp', 'feels_like_temp',
#        'hum', 'windspeed', 'users'],
#       dtype='object')

# %%
# Find the maximum value in each column
bikeshare_data.max(axis=0)
# Out:
# season                4.000000
# holiday               1.000000
# weekday               6.000000
# weathersit            3.000000
# temp                  0.861667
# feels_like_temp       0.840896
# hum                   0.972500
# windspeed             0.507463
# users              3410.000000
# dtype: float64

# %%
# Find the different vaues for season
# Find how many records are there for each season
bikeshare_data['season'].value_counts()
# Out:
# 3    188
# 2    184
# 1    181
# 4    178
# Name: season, dtype: int64

# %%
lst = [{"C1": 1, "C2": 2},
        {"C1": 5, "C2": 10, "C3": 20}]
lst_df = pd.DataFrame(lst)

# %%
lst_df
# Out:
#    C1  C2    C3
# 0   1   2   NaN
# 1   5  10  20.0

# %%
lst_df.isna()
# Out:
#       C1     C2     C3
# 0  False  False   True
# 1  False  False  False

# %%
lst_df > 10
# Out:
#       C1     C2     C3
# 0  False  False  False
# 1  False  False   True

# %%
lst_df + 5
# Out:
#    C1  C2    C3
# 0   6   7   NaN
# 1  10  15  25.0

# %%
bikeshare_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 9 columns):
# season             731 non-null int64
# holiday            731 non-null int64
# weekday            731 non-null int64
# weathersit         731 non-null int64
# temp               731 non-null float64
# feels_like_temp    731 non-null float64
# hum                731 non-null float64
# windspeed          731 non-null float64
# users              731 non-null int64
# dtypes: float64(4), int64(5)
# memory usage: 51.5 KB

# %%
bikeshare_data.index
# Out:
# RangeIndex(start=0, stop=731, step=1)

# %%
lst_df.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
lst_df.index = ['R1','R2']

# %%
lst_df
# Out:
#     C1  C2    C3
# R1   1   2   NaN
# R2   5  10  20.0

# %%
lst_df.loc["R1","C1"]
# Out:
# 1

# %%
lst_df[0:1]
# Out:
#     C1  C2  C3
# R1   1   2 NaN

# %%
bikeshare_data[0:5]
# Out:
#    season  holiday  weekday  weathersit      temp  feels_like_temp       hum  \
# 0       1        0        6           2  0.344167         0.363625  0.805833
# 1       1        0        0           2  0.363478         0.353739  0.696087
# 2       1        0        1           1  0.196364         0.189405  0.437273
# 3       1        0        2           1  0.200000         0.212122  0.590435
# 4       1        0        3           1  0.226957         0.229270  0.436957
#
#    windspeed  users
# 0   0.160446    331
# 1   0.248539    131
# 2   0.248309    120
# 3   0.160296    108
# 4   0.186900     82

# %%
bikeshare_data.iloc[0:5,0:3]
# Out:
#    season  holiday  weekday
# 0       1        0        6
# 1       1        0        0
# 2       1        0        1
# 3       1        0        2
# 4       1        0        3

# %%
df = pd.DataFrame([[0.23,'f1'],[5.36,'f2']],
                  index = list('pq'),
                    columns = list('ab'))

# %%
df
# Out:
#       a   b
# p  0.23  f1
# q  5.36  f2

# %%
df["c"] = np.random.rand(df.shape[0])

# %%
df
# Out:
#       a   b         c
# p  0.23  f1  0.159503
# q  5.36  f2  0.842846

# %%
df['a'] = df['a'].astype('complex')

# %%
df
# Out:
#            a   b         c
# p  (0.23+0j)  f1  0.159503
# q  (5.36+0j)  f2  0.842846

# %%
lst = ['f30','f50','f2','f0']

# %%
df[df.isin(lst).any(axis=1)]
# Out:
#            a   b         c
# q  (5.36+0j)  f2  0.842846

# %%
df[df.isin(lst)]
# Out:
#      a    b   c
# p  NaN  NaN NaN
# q  NaN   f2 NaN

# %%
df[df.isin(lst).any(axis=1)]
# Out:
#            a   b         c
# q  (5.36+0j)  f2  0.842846

# %%
# apply a function/evaluation over an axis
def fn_odd(x):
    return x%2!=0

# %%
fn_odd(3)
# Out:
# True

# %%
df2 = pd.DataFrame([{'a':1,'b':2},{'a':3,'b':4},{'a':5,'b':6}])

# %%
df2
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 2  5  6

# %%
df2.apply(fn_odd)
# Out:
#       a      b
# 0  True  False
# 1  True  False
# 2  True  False

# %%
bikeshare_data.to_excel('bike.xlsx',index=False)

# %%
l1 = [[1]*1000,[1]*1000]

# %%
# %%timeit

for i in l1:
    for j in range(0,len(i)):
        i[j]+=100
# Out:
# 205 µs ± 1.83 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
p = np.array([[1]*1000,[1]*1000])

# %%
# %%timeit
p+100
# Out:
# 3.03 µs ± 55 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# inplace

# %%
# drop

# %%
# reset_index()

# %%
# setting new index value

# %%
# set_index()

# %%
#groupby

# %%
#count

# %%
#map and filter
