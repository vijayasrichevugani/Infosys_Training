# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\hsbc_2019\\Desktop\\datasets\\bikesharedata.csv")

# %%
df.head()
# Out:
#    season  holiday  weekday  weathersit      temp     atemp       hum  \
# 0       1        0        6           2  0.344167  0.363625  0.805833
# 1       1        0        0           2  0.363478  0.353739  0.696087
# 2       1        0        1           1  0.196364  0.189405  0.437273
# 3       1        0        2           1  0.200000  0.212122  0.590435
# 4       1        0        3           1  0.226957  0.229270  0.436957
#
#    windspeed  users
# 0   0.160446    331
# 1   0.248539    131
# 2   0.248309    120
# 3   0.160296    108
# 4   0.186900     82

# %%
df[["users","temp"]].plot(kind="box")

# %%
df[["atemp","temp"]].plot(kind="box")
